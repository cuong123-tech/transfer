# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
transfer = pd.read_csv('Transfer.csv', encoding='Latin1')

# %%
transfer
# Out:
#                    Name  Age          Nationality          Position  \
# 0           Declan Rice   24      England Ireland  Central Midfield
# 1           Kai Havertz   24              Germany    Centre-Forward
# 2        Jurriën Timber   22  Netherlands Curacao        Right-Back
# 3            David Raya   27                Spain        Goalkeeper
# 4          Nuno Tavares   23  Portugal Cape Verde         Left-Back
# ..                  ...  ...                  ...               ...
# 235      Mahmoud Dahoud   27        Syria Germany  Central Midfield
# 236       Luca Unbehaun   22              Germany        Goalkeeper
# 237      Felix Passlack   25              Germany        Right-Back
# 238  Soumaïla Coulibaly   19          France Mali       Centre-Back
# 239         Nico Schulz   30              Germany         Left-Back
#
#                 Old_Club                New_Club            Fee  \
# 0        West Ham United              Arsenal FC       116.60m
# ...

# %%
transfer.info() # Get a quick description of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  240 non-null    object
#  1   Age                   240 non-null    int64
#  2   Nationality           240 non-null    object
#  3   Position              240 non-null    object
#  4   Old_Club              240 non-null    object
#  5   New_Club              240 non-null    object
#  6   Fee                   240 non-null    object
#  7   Minutes_This_Season   240 non-null    int64
#  8   Minutes_Last_season   240 non-null    int64
#  9   Standing_Last_Season  240 non-null    int64
#  10  Standing_This_Season  240 non-null    int64
#  11  Passes                240 non-null    int64
#  12  Assists               240 non-null    int64
#  13  Goals                 240 non-null    int64
#  14  Yellow_Card           240 non-null    int64
# ...

# %%
transfer['Nationality'].value_counts()
# Out:
# Nationality
# Spain              33
# Italy              25
# Germany            13
# France             10
# Brazil              6
#                    ..
# Japan               1
# Germany Austria     1
# Germany Kosovo      1
# Algeria             1
# Syria Germany       1
# Name: count, Length: 88, dtype: int64

# %%
transfer['Position'].value_counts()
# Out:
# Position
# Centre-Forward        35
# Centre-Back           34
# Goalkeeper            28
# Central Midfield      28
# Attacking Midfield    25
# Left-Back             17
# Right Winger          17
# Left Winger           16
# Right-Back            15
# Defensive Midfield    12
# Second Striker         6
# Right Midfield         3
# Left Midfield          3
# Spain                  1
# Name: count, dtype: int64

# %%
#Plot a histogram for each numerical attribute
transfer.hist(bins=50, figsize=(20,15))
plt.show()
